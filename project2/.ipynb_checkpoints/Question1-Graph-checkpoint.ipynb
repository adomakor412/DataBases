# %%
#from tkinter import *
import backend_graph as graph

# %%
'''INITIALIZE Database'''
sourceTitle = 'source'
targetTitle = 'target'
graph.initiateTable()
# Out:
# ['q']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in __call__(self, matchobj)
#      64         try:
# ---> 65             return self.params[index]
#      66         except IndexError:
#
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-2-f8e2063c5ff2> in <module>
#       2 sourceTitle = 'source'
#       3 targetTitle = 'target'
# ----> 4 graph.initiateTable()
#
# ~/COURSES/DataBases/project2/backend_graph.py in initiateTable()
#      26     for row in csv_data:
#      27         print(row)
# ---> 28         cur.execute('INSERT INTO DirectedEdges(source, target) VALUES("%s", "%s")', row)
#      29
#      30     conn.commit()
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     256             elif isinstance(prepared, (list, tuple)):
#     257                 psub = _ParamSubstitutor(prepared)
# --> 258                 stmt = RE_PY_PARAM.sub(psub, stmt)
#     259                 if psub.remaining != 0:
#     260                     raise errors.ProgrammingError(
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in __call__(self, matchobj)
#      66         except IndexError:
#      67             raise errors.ProgrammingError(
# ---> 68                 "Not enough parameters for the SQL statement")
#      69
#      70     @property
#
# ProgrammingError: Not enough parameters for the SQL statement

# %%
def checkConnected(source,target,length):
    connected = graph.checkConnected(source,target,length)
    return connected

checkConnected(0, 7, 1)

# %%
print(checkConnected(3, 12, 3))

# %%
def viewReversedEdges(m,n):
    return

# %%
def viewUndirectedEdges(m,n):
    return

# %%
import csv
with open('question1/graph.csv', newline='') as file:
    csv_data = csv.reader(file, delimiter=' ')
    for row in csv_data:
        print(str(csv_data))
# Out:
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>
# <_csv.reader object at 0x7fc752fc8850>

# %%
for row in csv_data:
    print(row)
# Out:
# ['q']
# ['u']
# ['e']
# ['s']
# ['t']
# ['i']
# ['o']
# ['n']
# ['1']
# ['/']
# ['g']
# ['r']
# ['a']
# ['p']
# ['h']
# ['.']
# ['c']
# ['s']
# ['v']
